# %% [markdown]
# # taking out a single row from a DataFrame

# %%
import pandas as pd

import numpy as np
v = np.random.randint(56,90,16)
v1 = np.random.randint(60,90,16)
v2 = np.random.randint(60,90,16)
data = pd.DataFrame({"name":['bi.bi.kutheja','chandrushekar','darshini'
                             ,'deepak','harsha','manasa','manoj',
                             'monstar','pavan','nisarga','priya',
                             'prajwal','shakthi','spoorthi','yashwanth.R',
                             'yashwanth.K.G'],
                     'year1':v,
                     'year2':v1,
                     'year3':v2})

print(data)
print("Value of row 1")
print(data.iloc[7])
# Out:
#              name  year1  year2  year3
# 0   bi.bi.kutheja     80     79     60
# 1   chandrushekar     61     72     73
# 2        darshini     65     89     67
# 3          deepak     68     84     84
# 4          harsha     87     79     60
# 5          manasa     88     85     68
# 6           manoj     74     62     83
# 7         monstar     70     79     82
# 8           pavan     88     63     87
# 9         nisarga     60     66     72
# 10          priya     69     65     81
# 11        prajwal     72     67     72
# 12        shakthi     61     85     77
# 13       spoorthi     76     80     61
# 14    yashwanth.R     57     84     66
# 15  yashwanth.K.G     58     65     77
# Value of row 1
# name     monstar
# year1         70
# year2         79
# year3         82
# Name: 7, dtype: object

# %% [markdown]
# # aggreagation sum() min() max()

# %%
print(data[data.year1==data.year1.max()])
print(data[data.year1==data.year1.min()])
print(data.year2)
# Out:
#             name  year1  year2  year3
# 1  chandrushekar     88     83     88
#     name  year1  year2  year3
# 8  pavan     58     61     58
# 0     77
# 1     83
# 2     80
# 3     86
# 4     64
# 5     68
# 6     83
# 7     69
# 8     61
# 9     61
# 10    74
# 11    82
# 12    62
# 13    69
# 14    86
# Name: year2, dtype: int32

# %% [markdown]
# # Group by

# %%
data = pd.read_csv('diamonds.csv')
data
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
data.head(7)
data.groupby(['cut']).mean()
# Out:
#              Unnamed: 0     carat      depth      table        price  \
# cut
# Fair       24147.357764  1.046137  64.041677  59.053789  4358.757764
# Good       24774.931309  0.849185  62.365879  58.694639  3928.864452
# Ideal      29047.630736  0.702837  61.709401  55.951668  3457.541970
# Premium    25600.209049  0.891955  61.264673  58.746095  4584.257704
# Very Good  26097.313193  0.806381  61.818275  57.956150  3981.759891
#
#                   x         y         z
# cut
# Fair       6.246894  6.182652  3.982770
# Good       5.838785  5.850744  3.639507
# Ideal      5.507451  5.520080  3.401448
# Premium    5.973887  5.944879  3.647124
# Very Good  5.740696  5.770026  3.559801

# %%
data.groupby(['cut','color']).agg('min')
# Out:
#                  Unnamed: 0  carat clarity  depth  table  price     x     y  \
# cut       color
# Fair      D             677   0.25      I1   52.2   52.0    536  4.09  4.11
#           E               9   0.22      I1   51.0   49.0    337  3.87  3.78
#           F              98   0.25      I1   52.3   50.0    496  4.19  4.15
#           G             228   0.23      I1   43.0   53.0    369  0.00  0.00
#           H             129   0.33      I1   52.7   50.0    659  4.40  4.32
#           I             353   0.41      I1   50.8   49.0    735  4.62  4.66
#           J             256   0.30      I1   55.0   52.0    416  4.24  4.16
# Good      D              43   0.23      I1   54.3   52.0    361  3.83  3.85
#           E               3   0.23      I1   56.3   53.0    327  3.83  3.85
#           F              36   0.23      I1   56.2   52.0    357  0.00  0.00
#           G             185   0.23      I1   56.2   53.0    394  3.94  3.90
# ...

# %%
f = {'price':['sum','min','max','mean','median','prod']}
data.groupby(['color']).agg(f)
print(data.groupby(['color']).agg(f))
# Out:
#           price
#             sum  min    max         mean  median prod
# color
# D      21476439  357  18693  3169.954096  1838.0  inf
# E      30142944  326  18731  3076.752475  1739.0  inf
# F      35542866  342  18791  3724.886397  2343.5  inf
# G      45158240  354  18818  3999.135671  2242.0  inf
# H      37257301  337  18803  4486.669196  3460.0  inf
# I      27608146  334  18823  5091.874954  3730.0  inf
# J      14949281  335  18710  5323.818020  4234.0  inf

# %% [markdown]
# # - Time Series Operations

# %% [markdown]
# ## Datetimeindex

# %%
data = pd.read_csv('apple.csv')
data.head(5)
type(data.Date[0])
# Out:
# str

# %%
data = pd.read_csv('apple.csv', parse_dates=['Date'])
data.head(5)
type(data.Date[0])
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.read_csv('apple.csv', parse_dates=['Date'],index_col=['Date'])
data.head(5)
data.index
# Out:
# DatetimeIndex(['2008-02-20', '2008-02-21', '2008-02-22', '2008-02-25',
#                '2008-02-26', '2008-02-27', '2008-02-28', '2008-02-29',
#                '2008-03-03', '2008-03-04',
#                ...
#                '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#                '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10',
#                '2022-11-11', '2022-11-14'],
#               dtype='datetime64[ns]', name='Date', length=3712, freq=None)

# %%
data['2017-01']
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_7652\717792658.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   data['2017-01']
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-01-03  28.950001  29.082500  28.690001  29.037500  27.174753  115127600
# 2017-01-04  28.962500  29.127501  28.937500  29.004999  27.144339   84472400
# 2017-01-05  28.980000  29.215000  28.952499  29.152500  27.282379   88774400
# 2017-01-06  29.195000  29.540001  29.117500  29.477501  27.586533  127007600
# 2017-01-09  29.487499  29.857500  29.485001  29.747499  27.839209  134247600
# 2017-01-10  29.692499  29.844999  29.575001  29.777500  27.867283   97848400
# 2017-01-11  29.684999  29.982500  29.650000  29.937500  28.017019  110354400
# ...

# %%
data['2017-01':'2017-06']
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2017-01-03  28.950001  29.082500  28.690001  29.037500  27.174753  115127600
# 2017-01-04  28.962500  29.127501  28.937500  29.004999  27.144339   84472400
# 2017-01-05  28.980000  29.215000  28.952499  29.152500  27.282379   88774400
# 2017-01-06  29.195000  29.540001  29.117500  29.477501  27.586533  127007600
# 2017-01-09  29.487499  29.857500  29.485001  29.747499  27.839209  134247600
# ...               ...        ...        ...        ...        ...        ...
# 2017-06-26  36.792500  37.070000  36.345001  36.455002  34.405766  102769600
# 2017-06-27  36.252499  36.540001  35.904999  35.932499  33.912643   99047600
# 2017-06-28  36.122501  36.527500  35.790001  36.457500  34.408127   88329600
# 2017-06-29  36.177502  36.282501  35.570000  35.919998  33.900829  125997600
# 2017-06-30  36.112499  36.240002  35.945000  36.005001  33.981060   92096400
#
# [125 rows x 6 columns]

# %% [markdown]
# ## Resample

# %%
data.Close.resample('M').mean()
# Out:
# Date
# 2008-02-29      4.382143
# 2008-03-31      4.672250
# 2008-04-30      5.649546
# 2008-05-31      6.598554
# 2008-06-30      6.374490
#                  ...
# 2022-07-31    149.670499
# 2022-08-31    166.885218
# 2022-09-30    153.002856
# 2022-10-31    145.013333
# 2022-11-30    143.107999
# Freq: M, Name: Close, Length: 178, dtype: float64

# %%
# %matplotlib inline
data.Close.resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## shift

# %%
data1 = data['2017':'2018']
data1['mean'] = data1['Low'].mean()
data1
# Out:
# C:\Users\revan\AppData\Local\Temp\ipykernel_7652\3965553717.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['mean'] = data1['Low'].mean()
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2017-01-03  28.950001  29.082500  28.690001  29.037500  27.174753  115127600
# 2017-01-04  28.962500  29.127501  28.937500  29.004999  27.144339   84472400
# 2017-01-05  28.980000  29.215000  28.952499  29.152500  27.282379   88774400
# 2017-01-06  29.195000  29.540001  29.117500  29.477501  27.586533  127007600
# 2017-01-09  29.487499  29.857500  29.485001  29.747499  27.839209  134247600
# ...               ...        ...        ...        ...        ...        ...
# ...

# %% [markdown]
# ## asfreq

# %%
data.asfreq('W',fill_value=3).head()
# Out:
#             Open  High  Low  Close  Adj Close  Volume
# Date
# 2008-02-24   3.0   3.0  3.0    3.0        3.0       3
# 2008-03-02   3.0   3.0  3.0    3.0        3.0       3
# 2008-03-09   3.0   3.0  3.0    3.0        3.0       3
# 2008-03-16   3.0   3.0  3.0    3.0        3.0       3
# 2008-03-23   3.0   3.0  3.0    3.0        3.0       3

# %% [markdown]
# ## seting a date

# %%
data = pd.read_csv('withourdate.csv')
date = pd.date_range(start='2008-02-20',end='2022-11-14',freq='B')
date
# Out:
# DatetimeIndex(['2008-02-20', '2008-02-21', '2008-02-22', '2008-02-25',
#                '2008-02-26', '2008-02-27', '2008-02-28', '2008-02-29',
#                '2008-03-03', '2008-03-04',
#                ...
#                '2022-11-01', '2022-11-02', '2022-11-03', '2022-11-04',
#                '2022-11-07', '2022-11-08', '2022-11-09', '2022-11-10',
#                '2022-11-11', '2022-11-14'],
#               dtype='datetime64[ns]', length=3844, freq='B')

# %%
data.set_index(date, inplace=True)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [157], in <cell line: 1>()
# ----> 1 data.set_index(date, inplace=True)
#       2 data
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5544, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5539             to_remove.append(col)
#    5541     if len(arrays[-1]) != len(self):
#    5542         # check newest element against length of calling frame, since
# ...

# %%
3844-
